# %%
##importing libraries
import pandas as pd

# %%
df = pd.read_csv("working_scrape.csv")
df
# Out:
#                                                   name           dates  \
# 0                                      Lekden Mahakala         Unknown
# 1                                  Medical Instruments         Unknown
# 2                           Phakpa Lokeshvara of Lhasa  Date uncertain
# 3                      Tibetan Sheep Bone Prayer Beads    date unknown
# 4                           Human Cranium Prayer Beads    Date unknown
# ..                                                 ...             ...
# 600             The Root of Treatment (chapters 5 & 6)       1995-1996
# 601                Knowledge of Dietetics (chapter 16)       1995-1996
# 602   Herbal and Animal Medications (chapter 20 cont.)       1995-1996
# 603  Supplementary Materia Medica II (chapter 20 co...       1995-1996
# 604  Perfection of Wisdom (Prajnaparmita) Sutra in ...            2001
#
#                                               province  \
# 0                                                Tibet
# ...

# %%
##what do we have
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             605 non-null    object
#  1   dates            605 non-null    object
#  2   province         605 non-null    object
#  3   mediums          605 non-null    object
#  4   classifications  605 non-null    object
#  5   object_numbers   605 non-null    object
#  6   on_views         605 non-null    object
#  7   donators         605 non-null    object
#  8   urls             605 non-null    object
# dtypes: object(9)
# memory usage: 42.7+ KB

# %%
##how many regions
print(df['province'].value_counts())
# Out:
# Tibet                                                                          315
# Chentsa, Amdo region, Northeastern Tibet (Jianzha, Qinghai Province, China)     80
# Central Tibet                                                                   52
# Kham Province, Eastern Tibet                                                    51
# Eastern Tibet                                                                   13
# Tsang Province, Central Tibet                                                    8
# Tibet or Mongolia                                                                8
# Western Tibet                                                                    8
# Kham Region, Eastern Tibet                                                       6
# Tibet or China                                                                   5
# Tibet or Bhutan                                                                  5
# ...

# %%
##of the 605 piece, 8 are unaccounted for clearly, unclear if they are from nepal or tibet
## 5 are either from bhutan or tibet. 5 are either from china or tibet
## 8 might be from either tibet or mongolia

# %%
df.query("`province` == 'Tibet or Mongolia'")
# Out:
#                                                name                dates  \
# 237         Guhyasamaja Akshobhyavajra with Consort  18th - 19th century
# 248                                       Hayagriva         18th century
# 301                                          Saddle  18th - 19th century
# 346          Makzor Gyelmo, Queen Who Repels Armies         19th century
# 408                                   Wheel of Life         19th century
# 414                A parcel-gilt silver ritual ewer         19th century
# 423  Green Tara as Protectress from the Eight Fears         19th century
# 519                         Hand-held Drum (Damaru)   early 20th century
#
#               province                                            mediums  \
# 237  Tibet or Mongolia                                  Pigments on cloth
# 248  Tibet or Mongolia                                   Pigments on wood
# 301  Tibet or Mongolia  wood, iron with gilding/silver plating, cloth,...
# ...

# %%
df.query("`province` == 'Tibet or China'")
# Out:
#                                                   name  \
# 175                               Bodhisattva Maitreya
# 178                              Bodhisattva Manjushri
# 188                                        Arhat Ajita
# 220  Fourth Demo Rinpoche, Lhawang Gyeltsen (1631–1...
# 376                     Hevajra with consort Nairatmya
#
#                           dates        province             mediums  \
# 175         17th - 18th century  Tibet or China   Pigments on cloth
# 178           17th-18th century  Tibet or China   Pigments on cloth
# 188                17th century  Tibet or China  Wood with pigments
# 220  Dated by inscription, 1667  Tibet or China   Pigments on cloth
# 376                19th century  Tibet or China     Silk embroidery
#
#     classifications object_numbers     on_views  \
# 175       paintings    C2006.66.34  Not on view
# 178       paintings     C2006.40.1  Not on view
# 188       sculpture     C2006.43.2  Not on view
# ...

# %%
df.query("`province` == 'Tibet or Bhutan'")
# Out:
#                                                   name  \
# 215                                  Buddha Shakyamuni
# 294                                      Padmasambhava
# 367  Loden Chokse, One of the Eight Manifestations ...
# 447  Dorje Drolo, One of the Eight Manifestations o...
# 458  Orgyen Dorje Chang, One of the Eight Manifesta...
#
#                       dates         province                    mediums  \
# 215  late 17th-18th century  Tibet or Bhutan  Silk Embroidery, Appliqué
# 294    18th or 19th century  Tibet or Bhutan          Gilt copper alloy
# 367            19th century  Tibet or Bhutan              Silk applique
# 447            19th century  Tibet or Bhutan           Textile applique
# 458            19th century  Tibet or Bhutan              Silk applique
#
#     classifications object_numbers     on_views  \
# 215        textiles     C2003.19.2  Not on view
# 294       sculpture        C2013.4  Not on view
# 367        textiles     C2003.34.1      On view
# ...

# %%
df.query("`province` == 'Tibet or Nepal'")
# Out:
#                                name                        dates  \
# 2        Phakpa Lokeshvara of Lhasa               Date uncertain
# 50   Hevajra with Consort Nairatmya  14th or 16th - 17th century
# 369             Red Avalokiteshvara                 19th century
# 492        Map of Drepung Monastery                   Dated 1898
#
#            province                                            mediums  \
# 2    Tibet or Nepal                    Wood with gold paint and colors
# 50   Tibet or Nepal  Copper alloy with copper and silver inlays and...
# 369  Tibet or Nepal                                  Pigments on cloth
# 492  Tibet or Nepal                                  Pigments on cloth
#
#     classifications object_numbers     on_views  \
# 2         sculpture    C2006.66.61  Not on view
# 50        sculpture     C2003.55.2      On view
# 369       paintings     F1996.18.2  Not on view
# 492       paintings      C2006.2.2  Not on view
#
# ...

# %%
df.query("`province` == 'Nepal or Tibet'")
# Out:
#                                      name                       dates  \
# 39                            Flying Naga                14th century
# 51   Sharabha; fragment of a throne frame         14th - 15th century
# 318                              Elephant                18th century
# 488                   Red Avalokiteshvara  dated by inscription, 1871
#
#            province                                            mediums  \
# 39   Nepal or Tibet                        Gilt copper alloy; repoussé
# 51   Nepal or Tibet  Gilt copper alloy, repoussé and traces of pigment
# 318  Nepal or Tibet                                          Metalwork
# 488  Nepal or Tibet                                  Pigments on cloth
#
#     classifications object_numbers     on_views  \
# 39        sculpture    C2005.16.18  Not on view
# 51        sculpture     C2004.14.9  Not on view
# 318       sculpture      C2021.3.1      On view
# 488       paintings     C2005.29.1      On view
#
# ...

# %%
##how many donators:
df["donators"].unique()
# Out:
# array(['Rubin Museum of Art',
#        'Rubin Museum of Art, Gift of Arnold Lieberman',
#        'Rubin Museum of Art, Gift of Shelley and Donald Rubin',
#        'Rubin Museum of Art, Gift of Anne Breckenridge Dorsey',
#        'Rubin Museum of Art, Gift of Michael McCormick',
#        'Rubin Museum of Art, Gift of the Shelley & Donald Rubin Foundation',
#        'Rubin Museum of Art, Gift of Dr. David Nalin',
#        'Rubin Museum of Art, Purchased from the Collection of Navin Kumar, New York',
#        'Rubin Museum of Art, Gift of John C. Rezk',
#        'Rubin Museum of Art, Gift of Anna Maria Rossi, Fabio Rossi',
#        'Rubin Museum of Art, Gift of Carlton Rochell',
#        'Rubin Museum of Art, Gift of Navin Kumar, New York City',
#        'Rubin Museum of Art, Gift of Carlton and Holly Rochell in honor of Donald Rubin',
#        'Rubin Museum of Art, Gift of Ralph Redford',
# ...

# %%
##how many times does each donor appear?
print(df['donators'].value_counts())
# Out:
# Rubin Museum of Art                                                                        214
# Rubin Museum of Art, Gift of Shelley and Donald Rubin                                      142
# Rubin Museum of Art, Gift of the Shelley & Donald Rubin Foundation                          80
# Rubin Museum of Art, Gift of Shelley and Donald Rubin Private Collection                    80
# Rubin Museum of Art, Gift of Anne Breckenridge Dorsey                                       29
# Rubin Museum of Art, Purchased from the Collection of Navin Kumar, New York                 13
# Rubin Museum of Art, Gift of Ralph Redford                                                   8
# Rubin Museum of Art, Gift of Robert and Lois Bayils                                          4
# Rubin Museum of Art, Gift of Dr. David Nalin                                                 4
# Rubin Museum of Art, Gift of Michael McCormick                                               3
# ...

# %%
##df_count is how many times the donor has appeared, the next following steps are turning these into dataframe 
##to export for dataframe
df_count
# Out:
# Rubin Museum of Art                                                                        214
# Rubin Museum of Art, Gift of Shelley and Donald Rubin                                      142
# Rubin Museum of Art, Gift of the Shelley & Donald Rubin Foundation                          80
# Rubin Museum of Art, Gift of Shelley and Donald Rubin Private Collection                    80
# Rubin Museum of Art, Gift of Anne Breckenridge Dorsey                                       29
# Rubin Museum of Art, Purchased from the Collection of Navin Kumar, New York                 13
# Rubin Museum of Art, Gift of Ralph Redford                                                   8
# Rubin Museum of Art, Gift of Robert and Lois Bayils                                          4
# Rubin Museum of Art, Gift of Dr. David Nalin                                                 4
# Rubin Museum of Art, Gift of Michael McCormick                                               3
# ...

# %%
df_count = df_count.reset_index()

# %%
df_count
# Out:
#                                                 index  donators
# 0                                 Rubin Museum of Art       214
# 1   Rubin Museum of Art, Gift of Shelley and Donal...       142
# 2   Rubin Museum of Art, Gift of the Shelley & Don...        80
# 3   Rubin Museum of Art, Gift of Shelley and Donal...        80
# 4   Rubin Museum of Art, Gift of Anne Breckenridge...        29
# 5   Rubin Museum of Art, Purchased from the Collec...        13
# 6          Rubin Museum of Art, Gift of Ralph Redford         8
# 7   Rubin Museum of Art, Gift of Robert and Lois B...         4
# 8        Rubin Museum of Art, Gift of Dr. David Nalin         4
# 9      Rubin Museum of Art, Gift of Michael McCormick         3
# 10                                               None         2
# 11  Rubin Museum of Art, From the Collection of Mr...         2
# 12  Rubin Museum of Art, Gift of Anna Maria Rossi,...         2
# 13      Rubin Museum of Art, Gift of Alice S. Kandell         2
# ...

# %%
df_count.rename(columns = {'index':'donors', 'donators': 'count'}, inplace = True)

# %%
df_count
# Out:
#                                                donors  count
# 0                                 Rubin Museum of Art    214
# 1   Rubin Museum of Art, Gift of Shelley and Donal...    142
# 2   Rubin Museum of Art, Gift of the Shelley & Don...     80
# 3   Rubin Museum of Art, Gift of Shelley and Donal...     80
# 4   Rubin Museum of Art, Gift of Anne Breckenridge...     29
# 5   Rubin Museum of Art, Purchased from the Collec...     13
# 6          Rubin Museum of Art, Gift of Ralph Redford      8
# 7   Rubin Museum of Art, Gift of Robert and Lois B...      4
# 8        Rubin Museum of Art, Gift of Dr. David Nalin      4
# 9      Rubin Museum of Art, Gift of Michael McCormick      3
# 10                                               None      2
# 11  Rubin Museum of Art, From the Collection of Mr...      2
# 12  Rubin Museum of Art, Gift of Anna Maria Rossi,...      2
# 13      Rubin Museum of Art, Gift of Alice S. Kandell      2
# ...

# %%
df_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   donors  34 non-null     object
#  1   count   34 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 672.0+ bytes

# %%
df_count
# Out:
#                                                donors  count
# 0                                 Rubin Museum of Art    214
# 1   Rubin Museum of Art, Gift of Shelley and Donal...    142
# 2   Rubin Museum of Art, Gift of the Shelley & Don...     80
# 3   Rubin Museum of Art, Gift of Shelley and Donal...     80
# 4   Rubin Museum of Art, Gift of Anne Breckenridge...     29
# 5   Rubin Museum of Art, Purchased from the Collec...     13
# 6          Rubin Museum of Art, Gift of Ralph Redford      8
# 7   Rubin Museum of Art, Gift of Robert and Lois B...      4
# 8        Rubin Museum of Art, Gift of Dr. David Nalin      4
# 9      Rubin Museum of Art, Gift of Michael McCormick      3
# 10                                               None      2
# 11  Rubin Museum of Art, From the Collection of Mr...      2
# 12  Rubin Museum of Art, Gift of Anna Maria Rossi,...      2
# 13      Rubin Museum of Art, Gift of Alice S. Kandell      2
# ...

# %%
##what objects are from shelley and donald private collection
df.query("`donators` == 'Rubin Museum of Art, Gift of Shelley and Donald Rubin Private Collection'")
# Out:
#                                                   name      dates  \
# 524  Primary and Secondary Causes of Disease XIII  ...  1995-1996
# 525  Pulse Examination IV   Seven Astonishing Pulse...  1995-1996
# 526  Urinalysis III   Pathological signs - Impendin...  1995-1996
# 527             Cathartic Procedures (chapter 14 - 17)  1995-1996
# 528  Moxibustion according to the King of the Moon ...  1995-1996
# ..                                                 ...        ...
# 599  Bloodletting channels and Moxibustion (chapter...  1995-1996
# 600             The Root of Treatment (chapters 5 & 6)  1995-1996
# 601                Knowledge of Dietetics (chapter 16)  1995-1996
# 602   Herbal and Animal Medications (chapter 20 cont.)  1995-1996
# 603  Supplementary Materia Medica II (chapter 20 co...  1995-1996
#
#                                               province            mediums  \
# 524  Chentsa, Amdo region, Northeastern Tibet (Jian...  Pigments on cloth
# ...

# %%
##pricol = donald and shelly private collection
df_pricol = df.query("`donators` == 'Rubin Museum of Art, Gift of Shelley and Donald Rubin Private Collection'")

# %%
##make it into its own dataframe for counts
df_pricol.reset_index()
# Out:
#     index                                             donors      dates  \
# 0     524  Primary and Secondary Causes of Disease XIII  ...  1995-1996
# 1     525  Pulse Examination IV   Seven Astonishing Pulse...  1995-1996
# 2     526  Urinalysis III   Pathological signs - Impendin...  1995-1996
# 3     527             Cathartic Procedures (chapter 14 - 17)  1995-1996
# 4     528  Moxibustion according to the King of the Moon ...  1995-1996
# ..    ...                                                ...        ...
# 75    599  Bloodletting channels and Moxibustion (chapter...  1995-1996
# 76    600             The Root of Treatment (chapters 5 & 6)  1995-1996
# 77    601                Knowledge of Dietetics (chapter 16)  1995-1996
# 78    602   Herbal and Animal Medications (chapter 20 cont.)  1995-1996
# 79    603  Supplementary Materia Medica II (chapter 20 co...  1995-1996
#
#                                              province            mediums  \
# ...

# %%
##what are the times 1995-96 comes up
print(df_pricol['dates'].value_counts())
# Out:
# 1995-1996    80
# Name: dates, dtype: int64

# %%
##what are these objects
print(df_pricol['name'].value_counts())
# Out:
# Herbal Medications (chapter 20 cont.)                                                                                 2
# Primary and Secondary Causes of Disease XIII   The Greater Elixir of Rejuvenation (chapter 90)                        1
# Cathartic Procedures and Bloodletting (chapters 18 - 20)                                                              1
# Conduct (chapters 13 - 15)                                                                                            1
# White Channels (chapter 4 cont.)                                                                                      1
#                                                                                                                      ..
# Course of the Lifespan Principle (chapter 4 cont.)                                                                    1
# Palace of the Buddha, Bhaisajyaguru, Master of Remedies (chapter 1)                                                   1
# ...

# %%
## this is interesting, all their private collections are pigments on cloth, paintings
## why is it dated 1995-1996?
