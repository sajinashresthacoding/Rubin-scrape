# %%
##import libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from random import randrange

# %%
pip install wget
# Out:
# Requirement already satisfied: wget in /Users/sajinashrestha/opt/anaconda3/lib/python3.9/site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import wget

# %%
def mk_request(url):
    '''
    Takes the url and gives you status and returns responses
    '''
    response = requests.get(url)
    if 200 <= response.status_code < 400:
        return response
    else:
        print(f"request returned {response.status_code}error")

# %%
## store the url

myurl = "https://collection.rubinmuseum.org/search/tibet"

# %%
mk_request(myurl)
# Out:
# <Response [200]>

# %%
## store the response
response = mk_request(myurl)

# %%
##making soup
def mk_soup(response):
    '''
    makes soup out of the response you give
    '''
    return BeautifulSoup(response.text, "html.parser")

# %%
## mother function that makes request and soup
def scrapes(url):
    '''
    give it a url to return docsoup of a page
    '''
    return mk_soup(mk_request(url))

# %%
tibet_soup = scrapes(myurl)
tibet_soup
# Out:
# <!DOCTYPE html>
# <html data-locale="en" lang="en" mobiletitle="true" xmlns="http://www.w3.org/1999/xhtml"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, maximum-scale=5" name="viewport"/><title>Search tibet (Objects) – Search – Rubin Museum of Art</title><link href="/assets/meta/z6a76c159/tapestry5/font_awesome/css/font-awesome.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/za5639df9/tapestry5/tapestry.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/ze8a5779c/tapestry5/exception-frame.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/zceffa0e4/tapestry5/tapestry-console.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/z7cd0b108/tapestry5/tree.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/core/zc5573d95/typeahead-bootstrap3.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/emuseumcommon/z63b0f4d8/jquery/jquery-ui/jquery-ui.min.css" rel="stylesheet" type="text/css"/><link href="/assets/meta/emuseumcore/z71b772e6/openlayers/ol.css" rel="stylesheet" type="text/css"/><style>@import url('https://fonts.googleapis.com/css?family=Lato');
# @import url('https://fonts.googleapis.com/css?family=Lora');
#
# :root {
#     /* ===== GLOBAL ===== */
#     --em-global-maxwidth-layout: 1400px;
#     --em-global-color-link: #1a1a1a;
#     --em-global-color-linkhover: #8c8585;
#     --em-global-color-basedark: #1a1a1a;
#     --em-global-color-highlight: #ee2b31;
#
#     /* ===== TYPOGRAPHY ===== */
#     --em-typography-font-body: 'Lato', sans-serif;
#     --em-typography-font-title: 'Lora', sans-serif;
#     --em-typography-font-basesize: 16px;
#
#     /* ===== HEADER ===== */
#     --em-header-padding-vertical: 30px;
#     --em-header-color-bg: #363632;
#     --em-header-color-text: #ffffff;
#
#     /* ===== FOOTER ===== */
#     --em-footer-padding-vertical: 30px;
#     --em-footer-color-bg: #f5f5f5;
#     --em-footer-color-text: #1a1a1a;
#
#     /* ===== HERO ===== */
#     --em-hero-bgposition-top: center;
#     --em-hero-height: 300px;
#
#     /* ===== GRID ===== */
#     --em-grid-width-gutter: 15px;
#
#     /* ===== DETAIL PAGE */
#     --em-mediazone-color-bg: #f5f5f5;
#
#     /* ===== Secret Options ===== */
#     --em-mosaicgrid-height-base: 700px;
#     --em-global-border-std: 1px solid #ccc;
#     --em-global-border-subtle: 1px solid rgba(0,0,0,0.11);
#     --em-global-border-bold: 2px solid var(--em-global-color-highlight);
# }
#
# /* ===== Secret Option! ===== */
# .emuseum-grid-border {
#     --em-grid-width-gutter: 0;
# }
# </style><link href="/assets/meta/emuseumcommon/z473bc543/font-awesome/css/font-awesome.min.css" media="screen" rel="stylesheet" type="text/css"/><link href="/assets/meta/emuseumcore/z54aa851/css/emuseum-skeleton.scss" media="screen" rel="stylesheet" type="text/css"/><!-- Rubin Assets --><link href="/assets/skin/2785ec30/images/favicon_16.ico" rel="icon" type="image/x-icon"/><link href="/assets/skin/d1e0283/images/favicon_32.png" rel="apple-touch-icon" sizes="32x32"/><link href="/assets/skin/7116421d/images/favicon_76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/assets/skin/7c837c1b/images/favicon_120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/assets/skin/9b897426/images/favicon_152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/assets/skin/d36e194a/images/favicon_180.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.2/jquery-ui.min.css" rel="stylesheet"/><link href="/assets/skin/za67b57dd/client/rubinmuseum.org_themes_site_themes_rubin_css_combinedPlugins.min.css" rel="stylesheet"/><style>
# @import url(//hello.myfonts.net/count/299673);
# .NeuzeitOffice-Bold,
# .NeuzeitOffice-BoldItalic,
# .NeuzeitOffice-Italic,
# .NeuzeitOffice-Medium {
# font-weight: 400;
# font-style: normal
# }
# @font-face {
# font-family: Swiss721BT-Light;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_0_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_0_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_0_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_0_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_0_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-LightItalic;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_1_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_1_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_1_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_1_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_1_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-Roman;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_2_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_2_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_2_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_2_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_2_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-Italic;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_3_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_3_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_3_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_3_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_3_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-Bold;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_4_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_4_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_4_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_4_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_4_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-BoldItalic;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_5_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_5_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_5_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_5_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_5_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-Medium;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_6_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_6_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_6_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_6_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_6_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: Swiss721BT-MediumItalic;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_7_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_7_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_7_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_7_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_7_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: NeuzeitOffice-Regular;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_8_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_8_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_8_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_8_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_8_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: NeuzeitOffice-Bold;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_9_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_9_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_9_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_9_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_9_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: NeuzeitOffice-BoldItalic;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_A_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_A_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_A_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_A_0.eot?#iefix) format('embedded-opentype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_A_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: NeuzeitOffice-Italic;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_B_0.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_B_0.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_B_0.eot), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_B_0.eot?#iefix) format('embedded-opentype') url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/299673_B_0.ttf) format('truetype');
# font-display: swap
# }
# @font-face {
# font-family: NeuzeitOffice-Medium;
# src: url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/neuzeitoffice-medium.woff2) format('woff2'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/neuzeitoffice-medium.woff) format('woff'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/neuzeitoffice-medium.eot), local('O'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/neuzeitoffice-medium.ttf) format('truetype'), url(https://rubinmuseum.org/themes/site_themes/rubin/css/webfonts/neuzeitoffice-medium.svg#NeuzeitOfficeMedium) format('svg');
# font-display: swap
# }
# .NeuzeitOffice-Medium {
# font-family: NeuzeitOffice-Medium
# }
# .NeuzeitOffice-Bold {
# font-family: NeuzeitOffice-Bold
# }
# .NeuzeitOffice-BoldItalic {
# font-family: NeuzeitOffice-BoldItalic
# }
# .NeuzeitOffice-Italic {
# font-family: NeuzeitOffice-Italic
# }
# .sidr {
# display: none;
# position: absolute;
# position: fixed;
# top: 0;
# height: 100%;
# z-index: 999999;
# width: 260px;
# overflow-x: none;
# overflow-y: auto
# }
# .sidr.right {
# left: auto;
# right: -260px
# }
# .sidr.left {
# left: -260px;
# right: auto
# }
# /*inline proform style to fix field to label alignment issue incurred after plugin upgrade */
# .proform .pf_column&gt;label {
# display: block
# }
# @media(inverted-colors) {
# img {
# filter: invert(100%)
# }
# }
# /*temp fix to address some instances where the button text was being pushed off it's axis 08-19-17 vincentbaker*/
# a[href*='tickets.rubinmuseum.org'].outline-button.red,
# a[href*='buy.acmeticketing.com'].outline-button.red {
# font-weight: 500 !important;
# }
# html {
# scroll-behavior: smooth;
# }
# </style><link href="/assets/skin/zcb482bc9/client/rubinmuseum.org_themes_site_themes_rubin_css_sass-bootstrap.css" rel="stylesheet"/><link href="/assets/skin/z8574be59/client/rubinmuseum.org_themes_site_themes_rubin_css_main.css" rel="stylesheet"/><!--[if lt IE 9]>
#         <script async src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#         <script async src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
#         <![endif]--><script async="true" src="//use.typekit.net/hjl5sji.js" type="text/javascript"></script><script type="text/javascript">
# try {
# Typekit.load();
# } catch (e) {}
# </script><!-- Google Tag Manager --><script>
# (function(w, d, s, l, i) {
# w[l] = w[l] || [];
# w[l].push({
# 'gtm.start': new Date().getTime(),
# event: 'gtm.js'
# });
# var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s),
# dl = l != 'dataLayer' ? '&amp;l=' + l : '';
# j.async = true;
# j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-MVLBR6');
# </script><!-- End Google Tag Manager --><!-- End Google Tag Manager (noscript) --><!-- Insert Client Styles before custom.scss --><link href="/assets/skin/z4f7e695f/css/custom.scss" media="screen" rel="stylesheet" type="text/css"/><link href="/assets/meta/emuseumcore/ze46e58a3/css/print.scss" rel="stylesheet" type="text/css"/><link href="/internal/customcssdispatcher" rel="stylesheet" type="text/css"/><meta content="emuseum" name="keywords"/><meta content="The Rubin Museum of Art is a dynamic environment that stimulates learning, promotes understanding, and inspires personal connections to the ideas, cultures, and art of Himalayan Asia." name="description"/><meta content="noindex" name="robots"/><!--[if IE 9]><style type="text/css">.pageloading-mask{opacity:0.25;}</style><![endif]--><!--[if lt IE 9]><style type="text/css">.pageloading-mask{filter:alpha(opacity=25);}</style><![endif]--></head><body class="show-covid em-sidebar-media-overlay search-Results-em-page em-transparent-detail-overlay emuseum em-skeleton-neue-theme contentHeader results-page objects-module contentHeaderTabs emuseum-no-rounded-corners results-grid-one-column emuseum-fit-grid" data-page-initialized="false"><!-- Use em-body-inner as direct child inside body to prevent horizontal scrolling on iOS landscape and leave
#              bottomRegion outside of it (modals) --><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MVLBR6" style="display:none;visibility:hidden" width="0"></iframe></noscript><style type="text/css">
# #news_slider{width:100%; background:#f00;}
# #news_slider{/* margin-left: 12.3%; */ height: 3em;padding-top: 1em;margin-bottom: 1em;}
# @media (max-width: 800px){
# #news_slider{margin-left:0px;height:6em;padding-top: 1em;margin-bottom: .2em;}
# }
# #news_slider .news_slider_text {color:#fff;font-size:16px;font-family: NeuzeitOffice-Medium,"Helvetica Neue",Arial,sans-serif;float:left;width:70%;max-width:61em;}
# @media (max-width: 414px){
# #news_slider .news_slider_text {width:76%}
# }
# #news_slider .news_slider_text a {color: #000; text-transform:uppercase;text-decoration: underline;}
# #news_slider #closeSlider{float:left;padding-right: 1em;top:1em}
# @media (max-width: 800px){
# #news_slider #closeSlider{margin-right: 5%}
# }
# #closeSlider:hover {cursor:pointer;}
# .spacer{width:18.5em;float:left;height:1em;}
# @media (max-width: 1280px){.spacer{width:16em}
# }
# @media (max-width: 1076px){.spacer{width:16em}
# }
# @media (max-width: 1024px){.spacer{width:7em}
# }
# @media (max-width: 800px){.spacer{width:2em}
# }
# @media (max-width: 768px){.spacer{width:6em}
# }
# @media (max-width: 414px){.spacer{width:3em}
# }
# </style><section class="covid-content" id="news_slider"><div class="spacer"> </div><div class="news_slider_text">The Rubin is open! <a href="https://rubinmuseum.org/visit/plan">PLAN YOUR VISIT.</a></div><div id="closeSlider"><svg height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg"><title>close-button</title><path d="M16,1.21L9.21,8,16,14.79,14.79,16,8,9.21,1.21,16,0,14.79,6.79,8,0,1.21,1.21,0,8,6.79,14.79,0Z" data-darkreader-inline-fill="" fill="white" style="--darkreader-inline-fill:currentColor;" transform="translate(0 0)"></path></svg></div></section><div class="em-body-inner"><!-- Rubin Mobile Header --><div class="mobile-header"><div class="container"><div class="row"><div class="col-xs-12"><a class="mobile-menu-button" href="#nav-menu">Mobile Menu Button</a><a href="https://rubinmuseum.org/"><img alt="The Rubin" src="/assets/skin/6edfcaa3/client/mobile-logo.png"/></a></div></div></div></div><!-- End Rubin Mobile Header --><div class="container top"><div class="row"><!-- Start nav-container --><div class="col-sm-0 col-md-2 flush-mobile nav-container"><nav class="nav-menu" id="nav-menu" role="navigation"><a href="https://rubinmuseum.org/"><img alt="The Rubin" class="top-logo" src="/assets/skin/1eba29ef/client/logo.png"/></a><ul class="main"><li><a class="" href="https://rubinmuseum.org/visit/plan">Visit</a><ul class=""><li><a class="" href="https://rubinmuseum.org/visit/plan">Plan a Visit</a></li><li><a class="" href="https://rubinmuseum.org/visit/tickets">Tickets</a></li><li><a class="" href="https://rubinmuseum.org/visit/tours">Tours and Groups</a></li><li><a class="" href="https://rubinmuseum.org/visit/dining">Dining at Café Serai</a></li><li><a class="" href="https://rubinmuseum.org/visit/accessibility">Accessibility</a></li></ul></li><li><a href="https://rubinmuseum.org/events">Exhibitions and Programs</a><ul class=""><li><a class="" href="https://rubinmuseum.org/theme/impermanence">2020 Theme: Impermanence</a></li><li><a class="" href="https://rubinmuseum.org/events">Events</a></li><li><a class="" href="https://rubinmuseum.org/events/series">Series</a></li><li><a class="" href="https://rubinmuseum.org/events/exhibitions">Exhibitions</a></li><li><a class="" href="https://rubinmuseum.org/events/itineraries">Itineraries</a></li><li><a class="" href="https://rubinmuseum.org/landing/nepal">Honoring Nepal</a></li></ul></li><li class="expanded"><a class="selected" href="https://rubinmuseum.org/collection/">Collection</a><ul class="open"><li><a class="" href="https://collection.rubinmuseum.org/?_ga=2.250613638.1806310695.1600887088-1047410676.1600364073">Collection Search</a></li><li><a class="" href="https://rubinmuseum.org/collection/about">About the Collection</a></li><li><a class="" href="https://rubinmuseum.org/collection/collecting-practices">Collecting Practices</a></li><li><a class="" href="https://rubinmuseum.org/collection/artoftheweek">Art of the Week</a></li><li><a class="" href="https://rubinmuseum.org/page/rubin-museum-publications">Publications</a></li></ul><div class="arrow"></div></li><li><a class="" href="https://rubinmuseum.org/spiral">Spiral Magazine</a><ul class=""><li><a class="" href="https://rubinmuseum.org/spiral/">2020: Impermanence Issue</a></li><li><a class="" href="https://rubinmuseum.org/spiral/power/index.html">2019: Power Issue</a></li><li><a class="" href="https://rubinmuseum.org/spiral/future/index.html">2018: Future Issue</a></li><li><a class="" href="https://rubinmuseum.org/spiral/sound/index.html">2017: Sound Issue</a></li></ul></li><li><a class="selected" href="https://rubinmuseum.org/mediacenter">Watch &amp; Listen</a><ul><li><a class="" href="https://rubinmuseum.org/landing/rubin-museum-audio-guides">Audio Tours</a></li><li><a class="" href="https://rubinmuseum.org/landing/awaken">Awaken Podcast</a></li><li><a class="" href="https://rubinmuseum.org/page/mindfulness-meditation-podcast">MM Podcast</a></li><li><a class="" href="https://rubinmuseum.org/mediacenter ...
# Collection
# </li></ul></div><div class="col-auto rubin-emuseum-menu"><div class="emuseum-menu-toggle">
# Collections Menu<span class="fa fa-angle-down em-icon"></span></div><nav aria-label="eMuseum Main Menu" class="nav emuseum-nav" id="emuseum-menu"><a class="nav-link null" href="/groups" title="Featured Collections">
# Featured Collections
# </a><a class="nav-link" href="/objects/images" title="All Works">
# All Artworks
# </a><a class="nav-link" href="/groups/on-view" title="On View">
# On View
# </a><a class="nav-link null" href="/rights" title="Image Rights">
# Image Rights
# </a><a class="nav-link null" href="/favorites/public" title="Favorites">
# Favorites
# </a></nav></div></div><!-- Start emuseum content --><div class="emuseum-main-wrap emuseum-bootstrap" id="emuseumMainWrap"><a href="#emuseum-main-content" id="emuseum-skip-navigation">Skip to main content</a><main class="emuseum-content" id="emuseum-main-content"><!-- The content header shows unless set to "false" in page template. --><div class="content-header"><!-- Show the title of the page if there is one and showTitle is not "false". --><div class="emuseum-title-wrap"><h1>Search</h1></div><!-- Show page specific header content if set --><!-- Module Tabs --><ul class="emuseum-header-tabs"><li class="active"><a href="/search/tibet/objects">
# Objects
# <span>
# (615)
# </span></a></li></ul></div><div class="qs-search-container"><div class="emuseum-quicksearch-wrap"><div class="emuseum-quicksearch-inner"><div class="emuseum-quicksearch"><form accept-charset="UTF-8" action="/search/results.layout.quicksearchform.searchform" data-generator="tapestry/core/form" id="searchForm" method="post"><input name="sid" type="hidden" value="tk8P93GFk7WOUnj3"/><input name="t:ac" type="hidden" value="tibet"/><input name="t:formdata" type="hidden" value="lj20LWI/6bosJC4EFZFs9zG987U=:"/><input aria-label="Keyword Search" autocomplete="off" class="form-control" id="quicksearchsuggest" name="quicksearchsuggest" placeholder="Search by keyword, title, country, or object number" type="text" value="tibet"/><input class="butgo" data-submit-mode="normal" id="submit_0" name="submit_0" type="submit" value="►"/><span class="fa fa-search qs-icon"></span></form></div><a class="bigsearch-advancedsearch-link" href="/advancedsearch">
# Advanced Search
# </a></div></div></div><div class="emuseum-css-grid results-grid"><div class="filter-wrapper grid-child"><div class="emuseum-filters"><span class="emuseum-filter-toggle emuseum-button emuseum-filter-toggle-close">Close <span class="fa fa-close"></span></span><div class="filter-headline">Refine Results</div><div class="filter-inner"><div class="filter-group-toggle filter-group filter-classifications"><div class="filter-header toggleLabel" tabindex="0"><span class="toggleIcon"></span><span>Classification(s)</span></div></div><div class="filter-items toggleContent filter-content-classifications"><div data-container-type="zone" id="filterMoreZone_0"><div class="filter-item"><a href="/search/tibet?filter=classifications%3Apaintings%0D#filters" rel="nofollow"><span class="filter-name">paintings
# </span><span class="filter-count">
# (373)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Asculpture#filters" rel="nofollow"><span class="filter-name">sculpture</span><span class="filter-count">
# (122)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Ascroll%20painting#filters" rel="nofollow"><span class="filter-name">scroll painting</span><span class="filter-count">
# (81)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Aritual%20objects#filters" rel="nofollow"><span class="filter-name">ritual objects</span><span class="filter-count">
# (58)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Amanuscripts#filters" rel="nofollow"><span class="filter-name">manuscripts</span><span class="filter-count">
# (23)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Afurniture#filters" rel="nofollow"><span class="filter-name">furniture</span><span class="filter-count">
# (18)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Atextiles#filters" rel="nofollow"><span class="filter-name">textiles</span><span class="filter-count">
# (10)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Adecorative%20arts#filters" rel="nofollow"><span class="filter-name">decorative arts</span><span class="filter-count">
# (4)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Aprints%20and%20drawings#filters" rel="nofollow"><span class="filter-name">prints and drawings</span><span class="filter-count">
# (3)
# </span></a></div><div class="filter-item"><a href="/search/tibet?filter=classifications%3Athangka#filters" rel="nofollow"><span class="filter-name">thangka</span><span class="filter-count">
# (3)
# </span></a></div><a class="emuseum-button" data-update-zone="filterMoreZone_0" href="/search/results.filterpanel.filtermorebutton/module/Objects/query/tibet/currentFilter/classifications?sid=tk8P93GFk7WOUnj3&amp;t:ac=tibet" rel="nofollow">
# Load all
# <span>Classification(s)</span></a></div></div><div class="filter-group-toggle filter-group filter-beginDate"><div class="filter-header toggleLabel" tabindex="0"><span class="toggleIcon"></span>Date
# </div></div><div class="filter-items toggleContent filter-content-beginDate"><div class="filter-item"><div data-date-max="2013" data-date-min="0" id="dateFilter"></div><form class="date-filter-form" id="dateFilterForm" ns0:autofocus="false" xmlns:ns0="http://tapestry.apache.org/schema/tapestry_5_4.xsd"><input aria-label="Begin date" class="form-control" id="beginDateFilter" max="2013" min="0" type="number" value="0"/><span class="date-range-between form-control">to</span><input aria-label="End date" class="form-control" id="endDateFilter" max="2013" min="0" type="number" value="2013"/><input class="emuseum-button" type="submit" value="Submit"/></form></div></div><!--  NOTHING TO SHOW - DEFERS TO filterbeginDate BLOCK --><div class="filter-group filter-group-boolean filter-mediaExistence"><form action="/search/results.filterpanel.mediafilterform" data-generator="tapestry/core/form" data-validate="submit" id="mediaFilterForm" method="post"><input name="sid" type="hidden" value="tk8P93GFk7WOUnj3"/><input name="t:ac" type="hidden" value="tibet"/><input name="t:formdata" type="hidden" value="3FbrxVpqrs9hV4AtQhMycIXUUdk=:..."/><input name="hidden" type="hidden" value=""/><div class="filter-header-boolean"><input aria-labelledby="mediaFilter-label" autocomplete="off" class="filterCB" id="mediaFilter" name="mediaFilter" onclick="this.form.submit()" tabindex="0" type="checkbox"/><label class="control-label" for="mediaFilter" id="mediaFilter-label">Image Available</label></div></form></div><div class="filter-group filter-group-boolean filter-onview"><form action="/search/results.filterpanel.onviewfilterform" data-generator="tapestry/core/form" data-validate="submit" id="onViewFilterForm" method="post"><input name="sid" type="hidden" value="tk8P93GFk7WOUnj3"/><input name="t:ac" type="hidden" value="tibet"/><input name="t:formdata" type="hidden" value="Wfq21x6N79CRECqwZ58emTS4TWE=:..."/><input name="hidden_1" type="hidden" value=""/><div class="filter-header-boolean"><input aria-labelledby="onViewFilter-label" autocomplete="off" class="filterCB" id="onViewFilter" name="onViewFilter" onclick="this.form.submit()" tabindex="0" type="checkbox"/><label class="control-label" for="onViewFilter" id="onViewFilter-label">On View</label></div></form></div><!-- Thesaurus: flat list --><!-- Thesaurus: tree --><!--
#             <t:block id="filterthesfilter">
#                 <div class="filter-group-toggle filter-group filter-${eognl:filter.facetField.name}">
#                     <div class="filter-header toggleLabel">
#                         <span class="toggleIcon"></span>${message:filterpanel.thesaurus-label}
#                     </div>
#                 </div>
#                 <div class="filter-items toggleContent filter-content-${eognl:filter.facetField.name}">
#                     <div class="filter-item">
#                         <div id="thesfilterTree"></div>
#                     </div>
#                 </div>
#             </t:block>
#             --></div></div></div><div class="results-wrapper grid-child"><div class="modules-active-1"><!-- 1. Result Tools --><div class="emuseum-result-tools"><!-- Sort and View Switcher --><form action="/search/results.sortswitcher.sortbyform" class="sort-by-form" data-generator="tapestry/core/form" data-validate="submit" id="sortByForm" method="post"><input name="sid" type="hidden" value="tk8P93GFk7WOUnj3"/><input name="t:ac" type="hidden" value="tibet"/><input name="t:formdata" type="hidden" value="XW3J45zLNDXRuNmuaaa1JCAHYho=:"/><span class="sort-by-label">Sort:</span><div class="select-wrapper sort-switcher-wrap"><select aria-label="Sort" class="form-control" id="select_3" name="select_3" onchange="this.form.submit()"><option value="">Relevance</option><option value="title-asc">Title (A–Z)</option><option value="displayDate-asc">Date (Older First)</option><option value="invno-asc">Object number (Ascending)</option><option value="primaryMakerAlpha-asc">Primary Maker (A-Z)</option><option value="recordLastUpdated-asc">Last Updated (Ascending)</option></select><input name="hidden" type="hidden" value=""/></div></form><form action="/search/results.viewswitcher.viewswitchform" class="view-switch-form" data-generator="tapestry/core/form" data-validate="submit" id="viewSwitchForm" method="post"><input name="sid" type="hidden" value="tk8P93GFk7WOUnj3"/><input name="t:ac" type="hidden" value="tibet"/><input name="t:formdata" type="hidden" value="fmqXPxkA43lbBjNFa89PEwQJW1o=:"/><div class="select-wrapper view-switcher-wrap active-view-images"><select aria-label="Switch Views" class="form-control" id="select_5" name="select_5" onchange="this.form.submit()"><option value="LIST">List</option><option selected="selected" value="IMAGES">Images</option><option value="TABLE">Table</option></select><input name="hidden" type="hidden" value=""/><input name="hidden_0" type="hidden" value="IMAGES"/></div></form></div><!-- 2. Results Actions --><div class="results-actions"><span class="emuseum-filter-toggle emuseum-button emuseum-filter-toggle-activate"><span class="fa fa-sliders em-icon"></span> Filters</span></div><!-- 3. Results Count and Favorites --><div class="row"><div class="col"><span class="result-details-result-count">615 results
#
# for
# <span class="result-details-title">tibet</span></span></div><div class="col col-auto text-right"></div></div><!-- 3a. Mobile Module Picker --><form action="/search/results.moduleform" class="header-tabs-form" data-generator="tapestry/core/form" data-validate="submit" id="moduleForm" method="post"><input name="sid" type="hidden" value="tk8P93GFk7WOUnj3"/><input name="t:ac" type="hidden" value="tibet"/><input name="t:formdata" type="hidden" value="iLpVeAyelYbeDw6Wlok1/MgGSFE=:"/><label class="control-label" for="moduleSelect" id="moduleSelect-label">Result type</label><select aria-labelledby="Result type" class="form-control" id="moduleSelect" name="moduleSelect" onchange="this.form.submit();"><option selected="selected" value="Objects">Objects</option></select></form><!-- 4. Filter Crumbs --><ul class="emuseum-filter-bar"><!-- default block --><!-- People --><!-- date range --></ul><!-- 5. No Results Message --><div id="imagesView"><div class="row flexgrid emuseum-img-grid" id="timagesview" perrow="4"><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="111721"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=0"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:65.66569209098816%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="Photograph by Bruce M. White, Rubin Museum of Art, 2008" class="" src="/internal/media/dispatcher/65282/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=0">The Demoness of Tibet</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">Early 20th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="111721" id="object_111721"></span></a></div><div class="toolbar-item"><!-- AddToAny BEGIN --><div class="a2a_kit a2a_kit_size_32 a2a_default_style" data-a2a-title="The Demoness of Tibet" data-a2a-url="https://collection.rubinmuseum.org/objects/291/the-demoness-of-tibet"><a class="a2a_dd" href="https://www.addtoany.com/share" rel="noopener noreferrer nofollow"></a></div></div><!-- AddToAny END --></span></span></div></div></div><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="111971"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=1"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:155.64202070236206%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="F1997.42.2" class="" src="/internal/media/dispatcher/9299/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type - ...
# After a woodblock carved in Derge, Kham region, eastern Tibet,
# composition attributed to Purbu Tsering of Chamdo (active ca. late 19th century)
# " data-a2a-url="https://collection.rubinmuseum.org/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha"><a class="a2a_dd" href="https://www.addtoany.com/share" rel="noopener noreferrer nofollow"></a></div></div><!-- AddToAny END --></span></span></div></div></div><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="111925"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=2"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:149.98979568481445%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="Photograph by David De Armas, Rubin Museum of Art, 2018" class="" src="/internal/media/dispatcher/65241/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=2">Chogyel Phakpa (1235–1280) initiating Qubilai Khan (1215–1294)</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">ca. 16th-17th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="111925" id="object_111925"></span></a></div><div class="toolbar-item"><!-- AddToAny BEGIN --><div class="a2a_kit a2a_kit_size_32 a2a_default_style" data-a2a-title="Chogyel Phakpa (1235–1280) initiating Qubilai Khan (1215–1294)" data-a2a-url="https://collection.rubinmuseum.org/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129"><a class="a2a_dd" href="https://www.addtoany.com/share" rel="noopener noreferrer nofollow"></a></div></div><!-- AddToAny END --></span></span></div></div></div><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="112215"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=3"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:144.22463178634644%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="Rubin Museum of Art" class="" src="/internal/media/dispatcher/46031/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=3">Indian Master Shantarakshita (active 8th century) and Scenes from his Life</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">19th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="112215" id="object_112215"></span></a></div><div class="toolbar ...
#                                     <div t:type="poweredBy"></div>
#                                     --><!-- Used mainly for context panel --></div><!-- end main wrap --><!-- end emuseum content --></div><!-- End .page.collection --></div><!-- end main-content --><!-- End main-content --></div><!-- end .row --></div><!-- end .container.top --><!-- Start Rubin Footer --><footer id="footer" role="contentinfo"><div class="container bottom"><div class="row"><div class="col-sm-12 col-lg-10 col-lg-offset-2"><div class="row"><div class="col-md-4 col-sm-6 address" typeof="TouristAttraction Museum" vocab="https://schema.org/"><h4 property="name">The Rubin Museum of Art</h4><p><address property="address" typeof="PostalAddress"><span property="streetAddress"> 150 West 17th St.</span><br/><span property="addressLocality">New York</span>, <span property="addressRegion">NY</span><span property="postalCode"> 10011</span><br/><span property="telephone"><a aria-label="2 1 2. 6 2 0. 5 0 0 0." class="tel" href="tel:+12126205000">(212) 620-5000</a></span></address></p></div><div class="col-md-4 col-sm-6 hour-grid" typeof="Museum" vocab="https://schema.org/"><h4>Hours</h4><div class="row"><!--<p style="margin-top:2px;margin-left:13px;" class="covid-content">The Museum is temporarily closed until <br/>further notice.</p>--><div class="col-xs-5 day">Monday</div><div class="col-xs-7 hours">Closed</div></div><div class="row"><div class="col-xs-5 day">Tuesday</div><div class="col-xs-7 hours">Closed</div></div><div class="row"><div class="col-xs-5 day">Wednesday</div><div class="col-xs-7 hours">Closed</div></div><!--
#                                     <div class="row">
#                                         <div class="col-xs-5 day">Thursday</div>
#                                         <div class="col-xs-7 hours">11:00 a.m.&mdash;5:00 p.m.
#                                             <meta property="openingHours" content="Th 11:00-17:00" />
#                                         </div>
#                                     </div>
#                                 --><div class="row"><div class="col-xs-5 day">Thursday</div><div class="col-xs-7 hours">11:00 AM — 5:00 PM<meta content="Th 11:00-17:00" property="openingHours"/></div><div class="col-xs-5 day"> </div><div class="col-xs-7 hours"> 10:00 AM — 11:00 AM <br/> Senior and high risk hours<meta content="Th 10:00-11:00 Senior Hours and High Risk Audiences" property="openingHours"/></div></div><div class="row"><div class="col-xs-5 day">Friday</div><div class="col-xs-7 hours">11:00 a.m.—10:00 p.m.
# <meta content="Fr 11:00-22:00" property="openingHours"/></div></div><div class="row"><div class="col-xs-5 day">Saturday/Sunday</div><div class="col-xs-7 hours">11:00 a.m.—5:00 p.m.
# <meta content="Sa Su 11:00-18:00" property="openingHours"/></div></div><!--<p><div class="outline-button" style="background:black; color:white;font-size:21px;width:6em;cursor:default;line-height: 40px;">UPDATE</div><br>
#                     <b>
#                     Due to ongoing mechanical work, the Museum is closed today.<br>
#         Our regularly scheduled Family Sunday art-making program will take place in the Museum's Education Center at 132 W 17th St. We apologize for the inconvenience.
#                     </b></p>--><p>The Museum is closed on Christmas,
# <br/>Thanksgiving, and New Year's Day.</p><p>The Museum closes one hour early on Christmas Eve and New Year’s Eve,
# and closes at 5:00 PM on the day after Thanksgiving. </p></div><div class="col-md-4 col-sm-6 site-links"><h4>Site Links</h4><ul class="bottom-menu left"><li><a href="https://rubinmuseum.org/visit/plan">Visit Us</a></li><li><a href="https://rubinmuseum.org/events">Event Calendar</a></li><li><a href="https://rubinmuseum.org/events/exhibitions">Current Exhibitions</a></li><li><a href="https://rubinmuseum.org/visit/tours">Tours and Groups</a></li><li><a href="https://rubinmuseum.org/education">Learn</a></li><li><a href="https://rubinmuseum.org/visit/accessibility">Accessibility</a></li><li><a href="https://rubinmuseum.org/visit/dining">Shop &amp; Dine</a></li></ul><ul class="bottom-menu right"><li><a href="https://rubinmuseum.org/support/membership">Membership</a></li><li><a href="https://rubinmuseum.org/support/donate">Donate</a></li><li><a href="https://rubinmuseum.org/about/space-rentals">Space Rentals</a></li><li><a href="https://rubinmuseum.org/about/press">For Press</a></li><li><a href="https://rubinmuseum.org/about/contact">Contact Us</a></li><li><a href="https://rubinmuseum.org/page/terms-and-conditions">Terms &amp; Conditions</a></li><li><a href="https://rubinmuseum.org/form/report_issue">Report an Issue</a></li></ul><div class="social-links"><a href="https://www.facebook.com/RubinMuseum" rel="noopener" target="_blank"><div class="facebook">facebook</div></a><a href="https://twitter.com/RubinMuseum" rel="noopener" target="_blank"><div class="twitter">twitter</div></a><a href="https://instagram.com/rubinmuseum/" rel="noopener" target="_blank"><div class="instagram">instagram</div></a><a href="https://www.youtube.com/user/RubinMuseum" rel="noopener" target="_blank"><div class="youtube">youtube</div></a><a href="https://www.tripadvisor.com/Attraction_Review-g60763-d548703-Reviews-Rubin_Museum_of_Art-New_York_City_New_York.html" rel="noopener" target="_blank"><div class="tripadvisor">trip advisor</div></a><div class="rss feeds">RSS</div><ul class="bottom-menu right feeds"><li class="blog_feed"><a href="https://feeds.feedburner.com/RubinmuseumBlog" rel="noopener" target="_blank"> Blog</a></li><li class="aotw_feed"><a href="https://feeds.feedburner.com/RubinmuseumArtoftheWeek" rel="noopener" target="_blank">Art of the Week</a></li><li class="events_feed"><a href="https://feeds.feedburner.com/EventsAtTheRubinMuseumOfArt" rel="noopener" target="_blank">Calendar</a></li></ul></div></div></div></div></div></div></footer><!-- end Footer --></div><!-- end em-body-inner --><div></div><script type="text/javascript">
# var a2a_config = a2a_config || {};
# a2a_config.prioritize = ["copy_link", "facebook", "twitter", "pinterest", "email"];
# a2a_config.num_services = 5;
# a2a_config.onclick = 1;
# a2a_config.icon_color = "transparent,black";
# </script><script async="async" src="//static.addtoany.com/menu/page.js"></script><!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-2376365-31"></script>;
# <script>
#  window.dataLayer = window.dataLayer || [];
#  function gtag(){dataLayer.push(arguments);}
#  gtag('js', new Date());
#
#  gtag('config', 'UA-2376365-31');
# </script>
# <!-- Sidr --><div class="sidr left" id="sidr"><nav class="sidr-inner"><a href="https://rubinmuseum.org/"><img alt="The Rubin" class="top-logo" src="/assets/skin/1eba29ef/client/logo.png"/></a><ul class="main"><li class="covid-content"><a class="" href="https://rubinmuseum.org/page/coronavirus-covid-19-closure-updates">Coronavirus Closure Updates</a></li><li class="covid-content"><a class="" href="https://rubinmuseum.org/landing/rubin-care-package-art-and-practices-for-navigating-your-world">Rubin Care Package</a></li><li class="covid-content"><a href="https://rubinmuseum.org/landing/the-rubin-daily-offering">The Rubin Daily Offering</a></li><li><a class="" href="https://rubinmuseum.org/visit/plan">Visit</a><ul class=""><li><a class="" href="https://rubinmuseum.org/visit/plan">Plan a Visit</a></li><li><a class="" href="https://rubinmuseum.org/visit/tickets">Tickets</a></li><li><a class="" href="https://rubinmuseum.org/visit/tours">Tours and Groups</a></li><li><a class="" href="https://rubinmuseum.org/visit/dining">Dining at Café Serai</a></li><li><a class="" href="https://rubinmuseum.org/visit/accessibility">Accessibility</a></li></ul></li><li><a href="https://rubinmuseum.org/events">Exhibitions and Programs</a><ul class=""><li><a class="" href="https://rubinmuseum.org/theme/impermanence">2020 Theme: Impermanence</a></li><li><a class="" href="https://rubinmuseum.org/events">Events</a></li><li><a class="" href="https://rubinmuseum.org/events/series">Series</a></li><li><a class="" href="https://rubinmuseum.org/events/exhibitions">Exhibitions</a></li><li><a class="" href="https://rubinmuseum.org/events/itineraries">Itineraries</a></li><li><a class="" href="https://rubinmuseum.org/landing/nepal">Honoring Nepal</a></li></ul></li><li class="expanded"><a class="" href="https://rubinmuseum.org/collection/">Collection</a><ul class="open"><li><a class="selected" href="https://collection.rubinmuseum.org/">Collection Search</a></li><li><a class="" href="https://rubinmuseum.org/collection/about">About the Collection</a></li><li><a class="" href="https://rubinmuseum.org/collection/collecting-practices">Collecting Practices</a></li><li><a class="" href="https://rubinmuseum.org/collection/artoftheweek">Art of the Week</a></li><li><a class="" href="https://rubinmuseum.org/page/rubin-museum-publications">Publications</a></li><!--
#                     <li>
#                         <a href="https://rubinmuseum.org/events/itineraries" class="">Art Itineraries</a>
#                     </li>
#                     --></ul><div class="arrow"></div></li><li><a class="" href="https://rubinmuseum.org/spiral">Spiral Magazine</a><ul class=""><li><a class="" href="https://rubinmuseum.org/spiral/">2020: Impermanence Issue</a></li><li><a class="" href="https://rubinmuseum.org/spiral/power/index.html">2019: Power Issue</a></li><li><a class="" href="https://rubinmuseum.org/spiral/future/index.html">2018: Future Issue</a></li><li><a class="" href="https://rubinmuseum.org/spiral/sound/index.html">2017: Sound Issue</a></li></ul></li><li><a class="selected" href="https://rubinmuseum.org/mediacenter">Watch &amp; Listen</a><ul><li><a class="" href="https://rubinmuseum.org/landing/rubin-museum-audio-guides">Audio Tours</a></li><li><a class="" href="https://rubinmuseum.org/landing/awaken">Awaken Podcast</a></li><li><a class="" href="https://rubinmuseum.org/page/mindfulness-meditation-podcast">MM Podcast</a></li><li><a class="" href="https://rubinmuseum.org/mediacenter">Videos on Demand</a></li></ul><div class="arrow"></div></li><li><a class="" href="https://rubinmuseum.org/landing/rubin-care-package-art-and-practices-for-navigating-your-world">Rubin Care Package</a></li></ul><ul class="secondary"><li><a href="https://rubinmuseum.org/about">About the Museum</a><ul class=""><li><a class="" href="https://rubinmuseum.org/about">About the Museum</a></li><li><a class="" href="https://rubinmuseum.org/about/founders">About the Founders</a></li><li><a class="" href="https://rubinmuseum.org/about/press">For Press</a></li><li><a class="" href="https://rubinmuseum.org/about/jobs">Jobs, Internships and Volunteering</a></li><li><a class="" href="https://rubinmuseum.org/about/staff-trustees">Staff and Trustees</a></li><li><a class="" href="https://rubinmuseum.org/about/contact">Contact</a></li></ul></li><li><a class="" href="https://rubinmuseum.org/support">Join and Support</a><ul class=""><li><a class="" href="https://rubinmuseum.org/support/membership">Membership</a></li><li><a class="" href="https://rubinmuseum.org/support/donate">Donate</a></li><li><a class="" href="https://rubinmuseum.org/support/corporate-support">Corporate Support</a></li><li><a class="" href="https://rubinmuseum.org/events/series/benefit-events">Benefit Events</a></li></ul></li><li><a class="" href="https://rubinmuseum.org/about/space-rentals">Space Rentals</a></li><li><a class="" href="https://shop.rubinmuseum.org">Shop</a></li><li><a class="" href="https://rubinmuseum.org/education">Learn</a><ul class=""><li><a class="" href="https://rubinmuseum.org/education">Search Resources</a></li><li><a class="" href="https://rubinmuseum.org/education/k-12-students">K-12</a></li><li><a class="" href="https://rubinmuseum.org/education/university-students">Universities</a></li><li><a class="" href="https://rubinmuseum.org/education/family-programs">Families</a></li><li><a class="" href="https://rubinmuseum.org/education/adult-education">Adults</a></li></ul></li><li><a class="" href="https://rubinmuseum.org/site/e-news">Signup for E-News</a><!-- <a href="https://rubinmuseum.us3.list-manage.com/subscribe/post?u=7bc1588b278eeab272a1ccb4d&id=976384051a" target="_blank" class="">Signup for E-News</a> --></li></ul><div class="social-links"><a href="https://www.facebook.com/RubinMuseum" rel="noopener" target="_blank"><div class="facebook">Facebook</div></a><a href="https://twitter.com/RubinMuseum" rel="noopener" target="_blank"><div class="twitter">Twitter</div></a><a href="https://instagram.com/rubinmuseum/" rel="noopener" target="_blank"><div class="instagram">Instagram</div></a><a href="https://www.youtube.com/user/RubinMuseum" rel="noopener" target="_blank"><div class="youtube">Youtube</div></a><a href="https://www.tripadvisor.com/Attraction_Review-g60763-d548703-Reviews-Rubin_Museum_of_Art-New_York_City_New_York.html" rel="noopener" target="_blank"><div class="tripadvisor">Tripadvisor</div></a></div><form action="https://rubinmuseum.org/" method="post"><div class="hiddenFields"><input name ...
#         <script>
#             window.jQuery || document.write('<script src="https://rubinmuseum.org/themes/site_themes/rubin/js/vendor/jquery-1.11.1.min.js"><\/script>')
#         </script>
#         --><script src="/assets/skin/za17e5617/client/rubinmuseum.org_themes_site_themes_rubin_js_vendor_jquery-1.11.1.min.js"></script><script src="//use.typekit.net/hjl5sji.js" type="text/javascript"></script><script src="/assets/skin/z92d32d0a/client/rubinmuseum.org_themes_site_themes_rubin_js_vendor_bootstrap.min.js"></script><script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.0/jquery-ui.min.js"></script><script src="/assets/skin/zb8884834/client/rubinmuseum.org_themes_site_themes_rubin_js_vendor_libs_rubinmuseum.org.min.js"></script><script>
# //this is to change the buy.acmeticketing.com links to tickets.rubinmuseum.org 08/10/17
# var $ahref = $('a[href*="buy.acmeticketing.com"]'),
# $a = $('a');
# if ($ahref.length) {
# $a.each(function(x) {
# $(this).attr('href', this.href.replace('buy.acmeticketing.com', 'tickets.rubinmuseum.org'));
# });
# }
# </script><script src="/assets/skin/zeaaf4dcb/client/rubinmuseum.org_themes_site_themes_rubin_js_main.min.js"></script><script type="text/javascript">var require = {"shim":{"t5/core/typeahead":["jquery"]},"baseUrl":"/modules.gz","waitSeconds":0};
# </script><script src="/assets/stack/zbb3f4a6b/en/core.js" type="text/javascript"></script><script type="text/javascript">require(["t5/core/pageinit"], function(pi) { pi(["/assets/meta/emuseumcore/z5abac47d/js/emuseum.js","/assets/skin/z407feea7/js/custom.js"], [["t5/core/autocomplete",{"id":"quicksearchsuggest","url":"/search/results.layout.quicksearchform.quicksearchsuggest:autocomplete?sid=tk8P93GFk7WOUnj3&t:ac=tibet","minChars":1,"limit":10}],"t5/core/forms","emuseum/QuickSearch","t5/core/zone",["emuseum/Filters:initFilters","/internal/thestree"],["emuseum/VirtualGroups:handleUrl","newGroupForm"],"emuseum/Favorites","emuseum/Grid:init",["emuseum/InfiniteScroll:init","Loading more results","Finished loading results"],["t5/core/pageinit:focus","quicksearchsuggest"]]); });</script></body></html>

# %%
all_objects = tibet_soup.find(id="timagesview")
all_objects
# Out:
# <div class="row flexgrid emuseum-img-grid" id="timagesview" perrow="4"><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="111721"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=0"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:65.66569209098816%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="Photograph by Bruce M. White, Rubin Museum of Art, 2008" class="" src="/internal/media/dispatcher/65282/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=0">The Demoness of Tibet</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">Early 20th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="111721" id="object_111721"></span></a></div><div class="toolbar-item"><!-- AddToAny BEGIN --><div class="a2a_kit a2a_kit_size_32 a2a_default_style" data-a2a-title="The Demoness of Tibet" data-a2a-url="https://collection.rubinmuseum.org/objects/291/the-demoness-of-tibet"><a class="a2a_dd" href="https://www.addtoany.com/share" rel="noopener noreferrer nofollow"></a></div></div><!-- AddToAny END --></span></span></div></div></div><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="111971"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=1"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:155.64202070236206%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="F1997.42.2" class="" src="/internal/media/dispatcher/9299/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=1">Renunciation, from a set of the Twelve Deeds of the Buddha, <br/>After a woodblock carved in Derge, Kham region, eastern Tibet, <br/>composition attributed to Purbu Tsering of Chamdo (active ca. late 19th century)</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">20th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="111971" id="object_111971"></span></a></div><div class="toolbar-item"><!-- AddToAny BEGIN --><div class="a2a_kit a2a_kit_size_32 a2a_default_style" data-a2a-title="Renunciation, from a set of the Twelve Deeds of the Buddha,
# After a woodblock carved in Derge, Kham region, eastern Tibet,
# composition attributed to Purbu Tsering of Chamdo (active ca. late 19th century)
# " data-a2a-url="https://collection.rubinmuseum.org/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha"><a class="a2a_dd" href="https://www.addtoany.com/share" rel="noopener noreferrer nofollow"></a></div></div><!-- AddToAny END --></span></span></div></div></div><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="111925"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=2"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:149.98979568481445%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="Photograph by David De Armas, Rubin Museum of Art, 2018" class="" src="/internal/media/dispatcher/65241/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=2">Chogyel Phakpa (1235–1280) initiating Qubilai Khan (1215–1294)</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">ca. 16th-17th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="111925" id="object_111925"></span></a></div><div class="toolbar-item"><!-- AddToAny BEGIN --><div class="a2a_kit a2a_kit_size_32 a2a_default_style" data-a2a-title="Chogyel Phakpa (1235–1280) initiating Qubilai Khan (1215–1294)" data-a2a-url="https://collection.rubinmuseum.org/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129"><a class="a2a_dd" href="https://www.addtoany.com/share" rel="noopener noreferrer nofollow"></a></div></div><!-- AddToAny END --></span></span></div></div></div><div class="result item grid-item col-lg-3 col-md-4 col-sm-4 col-6" data-emuseum-id="112215"><div class="grid-item-inner"><div class="primaryMedia img-wrap"><a href="/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=3"><div class="emuseum-img-wrap padded-img-wrap width-img-wrap emuseum-ratio-wrapper" data-mediatype-id="28" style="max-height:nullpx; max-width:650px; padding-bottom:144.22463178634644%"><div class="emuseum-loading"><i aria-hidden="true" class="fa fa-spinner fa-spin"></i></div><img alt="Rubin Museum of Art" class="" src="/internal/media/dispatcher/46031/thumbnail"/></div><!-- Zoom --><!-- Fullsize image --><!-- Any size --><!-- Image --><!-- Audio --><!-- Video --><!-- Document --><!-- Unknown/unsupported media type --></a></div><div class="texts-wrap"><div class="title text-wrap"><a class="" href="/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=3">Indian Master Shantarakshita (active 8th century) and Scenes from his Life</a></div><!-- Placeholder or empty value field --><span class="primaryMaker text-wrap holder-cell"></span><div class="displayDate text-wrap">19th century</div><!-- Placeholder or empty value field --><span class="shareToolbar text-wrap holder-cell"><span class="grid-item-toolbar"><div class="toolbar-item"><a href="/users/login?from=%25252Fsearch%25252Ftibet" rel="nofollow" title="Sign in"><span class="fa fa-heart-o mycollection-toggle" data-emuseum-id="112215" id="object_112215"></span></a></div><div class="toolbar ...

# %%
all_objects.find_all("div", class_="title")
# Out:
# [<div class="title text-wrap"><a class="" href="/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=0">The Demoness of Tibet</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=1">Renunciation, from a set of the Twelve Deeds of the Buddha, <br/>After a woodblock carved in Derge, Kham region, eastern Tibet, <br/>composition attributed to Purbu Tsering of Chamdo (active ca. late 19th century)</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=2">Chogyel Phakpa (1235–1280) initiating Qubilai Khan (1215–1294)</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=3">Indian Master Shantarakshita (active 8th century) and Scenes from his Life</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/1365/drenpa-namkha-ca-8th-century?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=4">Drenpa Namkha (ca. 8th century)</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/432/tara-protecting-from-the-eight-fears?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=5">Tara Protecting from the Eight Fears</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/458/sakya-pandita-11821251-and-chogyel-phakpa-12351280-wit?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=6">Sakya Pandita (1182-1251) and Chogyel Phakpa (1235-1280) with Mahakala Lineage Masters</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/1145/the-fifth-dalai-lama-ngawang-lobzang-gyatso-16171682-wit?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=7">The Fifth Dalai Lama, Ngawang Lobzang Gyatso (1617-1682) with Previous Incarnations</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/1453/namkha-pelzang-13981425?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=8">Namkha Pelzang (1398–1425)</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/37/buddha-shakyamuni?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=9">Buddha Shakyamuni</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/191/mahasiddha-virupa?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=10">Mahasiddha Virupa</a></div>,
#  <div class="title text-wrap"><a class="" href="/objects/433/bodhisattva?ctx=79f7c18e73a535be2ad44412484198763379ac7a&amp;idx=11">Bodhisattva</a></div>]

# %%
## where are the links being held
all_links = []
for link in tibet_soup.find(id="timagesview"):
    print(link.get('href'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
all_links
# Out:
# ['https://rubinmuseum.org/visit/plan',
#  '#nav-menu',
#  'https://rubinmuseum.org/',
#  'https://rubinmuseum.org/',
#  'https://rubinmuseum.org/visit/plan',
#  'https://rubinmuseum.org/visit/plan',
#  'https://rubinmuseum.org/visit/tickets',
#  'https://rubinmuseum.org/visit/tours',
#  'https://rubinmuseum.org/visit/dining',
#  'https://rubinmuseum.org/visit/accessibility',
#  'https://rubinmuseum.org/events',
#  'https://rubinmuseum.org/theme/impermanence',
#  'https://rubinmuseum.org/events',
#  'https://rubinmuseum.org/events/series',
#  'https://rubinmuseum.org/events/exhibitions',
#  'https://rubinmuseum.org/events/itineraries',
#  'https://rubinmuseum.org/landing/nepal',
#  'https://rubinmuseum.org/collection/',
#  'https://collection.rubinmuseum.org/?_ga=2.250613638.1806310695.1600887088-1047410676.1600364073',
#  'https://rubinmuseum.org/collection/about',
#  'https://rubinmuseum.org/collection/collecting-practices',
#  'https://rubinmuseum.org/collection/artoftheweek',
#  'https://rubinmuseum.org/page/rubin-museum-publications',
#  'https://rubinmuseum.org/spiral',
#  'https://rubinmuseum.org/spiral/',
#  'https://rubinmuseum.org/spiral/power/index.html',
#  'https://rubinmuseum.org/spiral/future/index.html',
#  'https://rubinmuseum.org/spiral/sound/index.html',
#  'https://rubinmuseum.org/mediacenter',
#  'https://rubinmuseum.org/landing/rubin-museum-audio-guides',
#  'https://rubinmuseum.org/landing/awaken',
#  'https://rubinmuseum.org/page/mindfulness-meditation-podcast',
#  'https://rubinmuseum.org/mediacenter',
#  'https://rubinmuseum.org/landing/rubin-care-package-art-and-practices-for-navigating-your-world',
#  'https://rubinmuseum.org/about',
#  'https://rubinmuseum.org/about',
#  'https://rubinmuseum.org/about/founders',
#  'https://rubinmuseum.org/about/press',
#  'https://rubinmuseum.org/about/jobs',
#  'https://rubinmuseum.org/about/staff-trustees',
#  'https://rubinmuseum.org/about/contact',
#  'https://rubinmuseum.org/support',
#  'https://rubinmuseum.org/support/membership',
#  'https://rubinmuseum.org/support/donate',
#  'https://rubinmuseum.org/support/corporate-support',
#  'https://rubinmuseum.org/events/series/benefit-events',
#  'https://rubinmuseum.org/space-rentals',
#  'https://shop.rubinmuseum.org',
#  'https://rubinmuseum.org/education',
#  'https://rubinmuseum.org/education',
#  'https://rubinmuseum.org/education/k-12-students',
#  'https://rubinmuseum.org/education/university-students',
#  'https://rubinmuseum.org/education/family-programs',
#  'https://rubinmuseum.org/education/adult-education',
#  'https://rubinmuseum.org/site/e-news',
#  'https://www.facebook.com/RubinMuseum',
#  'https://twitter.com/RubinMuseum',
#  'https://instagram.com/rubinmuseum/',
#  'https://www.youtube.com/user/RubinMuseum',
#  'https://www.tripadvisor.com/Attraction_Review-g60763-d548703-Reviews-Rubin_Museum_of_Art-New_York_City_New_York.html',
#  '/groups',
#  '/objects/images',
#  '/groups/on-view',
#  '/rights',
#  '/favorites/public',
#  '#emuseum-main-content',
#  '/search/tibet/objects',
#  '/advancedsearch',
#  '/search/tibet?filter=classifications%3Apaintings%0D#filters',
#  '/search/tibet?filter=classifications%3Asculpture#filters',
#  '/search/tibet?filter=classifications%3Ascroll%20painting#filters',
#  '/search/tibet?filter=classifications%3Aritual%20objects#filters',
#  '/search/tibet?filter=classifications%3Amanuscripts#filters',
#  '/search/tibet?filter=classifications%3Afurniture#filters',
#  '/search/tibet?filter=classifications%3Atextiles#filters',
#  '/search/tibet?filter=classifications%3Adecorative%20arts#filters',
#  '/search/tibet?filter=classifications%3Aprints%20and%20drawings#filters',
#  '/search/tibet?filter=classifications%3Athangka#filters',
#  '/search/results.filterpanel.filtermorebutton/module/Objects/query/tibet/currentFilter/classifications?sid=tk8P93GFk7WOUnj3&t:ac=tibet',
#  '/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=0',
#  '/objects/291/the-demoness-of-tibet?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=0',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=1',
#  '/objects/1362/renunciation-from-a-set-of-the-twelve-deeds-of-the-buddha?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=1',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=2',
#  '/objects/1208/chogyel-phakpa-12351280-initiating-qubilai-khan-1215129?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=2',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=3',
#  '/objects/2481/indian-master-shantarakshita-active-8th-century-and-scenes?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=3',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/1365/drenpa-namkha-ca-8th-century?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=4',
#  '/objects/1365/drenpa-namkha-ca-8th-century?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=4',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/432/tara-protecting-from-the-eight-fears?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=5',
#  '/objects/432/tara-protecting-from-the-eight-fears?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=5',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/458/sakya-pandita-11821251-and-chogyel-phakpa-12351280-wit?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=6',
#  '/objects/458/sakya-pandita-11821251-and-chogyel-phakpa-12351280-wit?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=6',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/1145/the-fifth-dalai-lama-ngawang-lobzang-gyatso-16171682-wit?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=7',
#  '/objects/1145/the-fifth-dalai-lama-ngawang-lobzang-gyatso-16171682-wit?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=7',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/1453/namkha-pelzang-13981425?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=8',
#  '/objects/1453/namkha-pelzang-13981425?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=8',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/37/buddha-shakyamuni?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=9',
#  '/objects/37/buddha-shakyamuni?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=9',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/191/mahasiddha-virupa?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=10',
#  '/objects/191/mahasiddha-virupa?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=10',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/objects/433/bodhisattva?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=11',
#  '/objects/433/bodhisattva?ctx=79f7c18e73a535be2ad44412484198763379ac7a&idx=11',
#  '/users/login?from=%25252Fsearch%25252Ftibet',
#  'https://www.addtoany.com/share',
#  '/search/tibet/objects/images?page=2',
#  'tel:+12126205000',
#  'https://rubinmuseum.org/visit/plan',
#  'https://rubinmuseum.org/events',
#  'https://rubinmuseum.org/events/exhibitions',
#  'https://rubinmuseum.org/visit/tours',
#  'https://rubinmuseum.org/education',
#  'https://rubinmuseum.org/visit/accessibility',
#  'https://rubinmuseum.org/visit/dining',
#  'https://rubinmuseum.org/support/membership',
#  'https://rubinmuseum.org/support/donate',
#  'https://rubinmuseum.org/about/space-rentals',
#  'https://rubinmuseum.org/about/press',
#  'https://rubinmuseum.org/about/contact',
#  'https://rubinmuseum.org/page/terms-and-conditions',
#  'https://rubinmuseum.org/form/report_issue',
#  'https://www.facebook.com/RubinMuseum',
#  'https://twitter.com/RubinMuseum',
#  'https://instagram.com/rubinmuseum/',
#  'https://www.youtube.com/user/RubinMuseum',
#  'https://www.tripadvisor.com/Attraction_Review-g60763-d548703-Reviews-Rubin_Museum_of_Art-New_York_City_New_York.html',
#  'https://feeds.feedburner.com/RubinmuseumBlog',
#  'https://feeds.feedburner.com/RubinmuseumArtoftheWeek',
#  'https://feeds.feedburner.com/EventsAtTheRubinMuseumOfArt',
#  'https://rubinmuseum.org/',
#  'https://rubinmuseum.org/page/coronavirus-covid-19-closure-updates',
#  'https://rubinmuseum.org/landing/rubin-care-package-art-and-practices-for-navigating-your-world',
#  'https://rubinmuseum.org/landing/the-rubin-daily-offering',
#  'https://rubinmuseum.org/visit/plan',
#  'https://rubinmuseum.org/visit/plan',
#  'https://rubinmuseum.org/visit/tickets',
#  'https://rubinmuseum.org/visit/tours',
#  'https://rubinmuseum.org/visit/dining',
#  'https://rubinmuseum.org/visit/accessibility',
#  'https://rubinmuseum.org/events',
#  'https://rubinmuseum.org/theme/impermanence',
#  'https://rubinmuseum.org/events',
#  'https://rubinmuseum.org/events/series',
#  'https://rubinmuseum.org/events/exhibitions',
#  'https://rubinmuseum.org/events/itineraries',
#  'https://rubinmuseum.org/landing/nepal',
#  'https://rubinmuseum.org/collection/',
#  'https://collection.rubinmuseum.org/',
#  'https://rubinmuseum.org/collection/about',
#  'https://rubinmuseum.org/collection/collecting-practices',
#  'https://rubinmuseum.org/collection/artoftheweek',
#  'https://rubinmuseum.org/page/rubin-museum-publications',
#  'https://rubinmuseum.org/spiral',
#  'https://rubinmuseum.org/spiral/',
#  'https://rubinmuseum.org/spiral/power/index.html',
#  'https://rubinmuseum.org/spiral/future/index.html',
#  'https://rubinmuseum.org/spiral/sound/index.html',
#  'https://rubinmuseum.org/mediacenter',
#  'https://rubinmuseum.org/landing/rubin-museum-audio-guides',
#  'https://rubinmuseum.org/landing/awaken',
#  'https://rubinmuseum.org/page/mindfulness-meditation-podcast',
#  'https://rubinmuseum.org/mediacenter',
#  'https://rubinmuseum.org/landing/rubin-care-package-art-and-practices-for-navigating-your-world',
#  'https://rubinmuseum.org/about',
#  'https://rubinmuseum.org/about',
#  'https://rubinmuseum.org/about/founders',
#  'https://rubinmuseum.org/about/press',
#  'https://rubinmuseum.org/about/jobs',
#  'https://rubinmuseum.org/about/staff-trustees',
#  'https://rubinmuseum.org/about/contact',
#  'https://rubinmuseum.org/support',
#  'https://rubinmuseum.org/support/membership',
#  'https://rubinmuseum.org/support/donate',
#  'https://rubinmuseum.org/support/corporate-support',
#  'https://rubinmuseum.org/events/series/benefit-events',
#  'https://rubinmuseum.org/about/space-rentals',
#  'https://shop.rubinmuseum.org',
#  'https://rubinmuseum.org/education',
#  'https://rubinmuseum.org/education',
#  'https://rubinmuseum.org/education/k-12-students',
#  'https://rubinmuseum.org/education/university-students',
#  'https://rubinmuseum.org/education/family-programs',
#  'https://rubinmuseum.org/education/adult-education',
#  'https://rubinmuseum.org/site/e-news',
#  'https://www.facebook.com/RubinMuseum',
#  'https://twitter.com/RubinMuseum',
#  'https://instagram.com/rubinmuseum/',
#  'https://www.youtube.com/user/RubinMuseum',
#  'https://www.tripadvisor.com/Attraction_Review-g60763-d548703-Reviews-Rubin_Museum_of_Art-New_York_City_New_York.html']

# %%
tibetan_objects = []
other_links = []

for single_link in all_links:
    if single_link.startswith("'/objects/"):
        tibetan_objects.append(single_link.startswith("'/objects/"))
    else:
        other_links.append(single_link)

# %%
tibetan_objects
# Out:
# []
